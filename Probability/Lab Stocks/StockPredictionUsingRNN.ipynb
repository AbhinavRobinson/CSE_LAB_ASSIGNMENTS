# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavRobinson/CSE_LAB_ASSIGNMENTS/blob/master/StockPredictionUsingRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Prediction Using RNN
# ##For Education Use Only
# > Disclaimer : Do Not use this for real world purposes
#
# Hi there!
#
# In this Assignment of EMAT203L , We make a stock prediction algorithm.
#
# One way to achive this is using RNN, implemented via TensorFlow.
# We will be using TensorFlow 1.15 for this. This program may not be compatible with TensorFlow 2.X.X.
# Read the Documentation carefully!
#
# -Abhinav Robinson :)

# %% [markdown]
# #Method
#
# We are only concerned with the "Close" data at this moment.
# Hence we will use pandas to cleanup the data, enter data inside a Dataframe, with only the relavant columns.

# %%
import pandas as pd

# Lets check the data :)
main_df = pd.DataFrame()

# Lets combine all data in one dataframe
ratios = ["BJB-INR","BBA-INR","PNB-INR","YES-INR"]
for ratio in ratios:
  dataset = f"{ratio}.csv"
  df = pd.read_csv(dataset,  
                   names=["time","open","high","low","close"])

  df.rename(columns={"close": f"{ratio}_close"}, 
            inplace=True)
  df.set_index("time",inplace=True)
  df = df[[f"{ratio}_close"]]

  if len(main_df) == 0:
    main_df = df
  else:
    main_df = main_df.join(df)

# Lets Test our data cleanup
print(main_df.head())
# Out:
#             BJB-INR_close  BBA-INR_close  PNB-INR_close  YES-INR_close
# time
# 30-08-2019        3332.50          92.60          64.90          59.95
# 29-08-2019        3299.30          91.80          65.05          57.40
# 28-08-2019        3326.35          94.50          65.65          59.50
# 27-08-2019        3357.75          97.30          67.15          64.50
# 26-08-2019        3324.25          95.05          65.75          62.90

# %%
import time
# Now we define some time variables
# Based on last 15 days
SEQ_LEN = 20
# We predict next 3 day
# We will be going 3 divisions ahead, as a rule of thumb
FUTURE_PERIOD_PREDICT = 3
# on the YesBank EQ Close
RATIO_TO_PREDICT = "PNB-INR"
# Defining no. of EPOCHS
EPOCHS = 12
# Defining Batch Size
BATCH_SIZE = 64
# Adding Names
NAME = f"{SEQ_LEN}-SEQ-{FUTURE_PERIOD_PREDICT}-PRED-{int(time.time())}"

# %%
def classify(current, future):
  # aka, good thing, buy
  if float(future) > float(current): return 1
  # not a good thing, maybe? ;)
  else: return 0

# %%
# Lets add future price as a column
main_df['future'] = main_df[f"{RATIO_TO_PREDICT}_close"].shift(-FUTURE_PERIOD_PREDICT)
print(main_df[[f"{RATIO_TO_PREDICT}_close", "future"]].head())
# Out:
#             PNB-INR_close  future
# time
# 29-08-2019          65.05   65.75
# 28-08-2019          65.65   63.60
# 27-08-2019          67.15   61.45
# 26-08-2019          65.75   64.05
# 23-08-2019          63.60   65.60

# %%
# add output of classify to a list shown as a column
main_df['target'] = list(map(classify, 
                             main_df[f"{RATIO_TO_PREDICT}_close"],
                             main_df["future"]))

print(main_df[[f"{RATIO_TO_PREDICT}_close", "future", "target"]].head(10))
# Out:
#             PNB-INR_close  future  target
# time
# 29-08-2019          65.05   65.75       1
# 28-08-2019          65.65   63.60       0
# 27-08-2019          67.15   61.45       0
# 26-08-2019          65.75   64.05       0
# 23-08-2019          63.60   65.60       1
# 22-08-2019          61.45   67.30       1
# 21-08-2019          64.05   68.10       1
# 20-08-2019          65.60   65.55       0
# 19-08-2019          67.30   65.35       0
# 16-08-2019          68.10   66.55       0

# %%
# Noramlly data is sorted, but just in case
# .values converts index values to numpy array
times = sorted(main_df.index.values)
# now we seperate the last 5% data for test data
# last_5pct is a unix timestamp
last_5pct = times[-int(0.05*len(times))]

# Now we split the data
validation_main_df = main_df[(main_df.index >= last_5pct)]
main_df = main_df[(main_df.index < last_5pct)]

# %%
# Import some more libraries ;_;
from sklearn import preprocessing
from collections import deque
import random
import numpy as np

# Preprocess DF to scale all values of diff. coins on one scale
# and add percent change
def preprocess_df(df):
  df = df.drop('future',1)

  for col in df.columns:
    if col != 'target':
      df[col] = df[col].pct_change()
      df.dropna(inplace=True)
      df[col] = preprocessing.scale(df[col].values)

  df.dropna(inplace=True)

  sequential_data = []
  prev_days = deque(maxlen = SEQ_LEN)
  print(df.head())

  for i in df.values:
    prev_days.append([n for n in i[:-1]]) 
    if len(prev_days) == SEQ_LEN:
      sequential_data.append([np.array(prev_days), i[-1]])

  random.shuffle(sequential_data)

  buys = []
  sells = []

  for seq, target, in sequential_data:
    if target == 0:
      sells.append([seq, target])
    elif target == 1:
      buys.append([seq, target])

  random.shuffle(buys)
  random.shuffle(sells)

  lower = min(len(buys), len(sells))

  # Upto 30K
  buys = buys[:lower]
  sells = sells[:lower]

  sequential_data = buys+sells
  random.shuffle(sequential_data)

  X = []
  y = []

  for seq,target in sequential_data:
    X.append(seq)
    y.append(target)

  return np.array(X), y

# %%
train_x , train_y = preprocess_df(main_df)
validation_x , validation_y = preprocess_df(validation_main_df)
# Out:
#             BJB-INR_close  BBA-INR_close  PNB-INR_close  YES-INR_close  target
# time
# 21-08-2019       2.130906       1.784758       1.622452       5.284787       1
# 20-08-2019       0.519015       1.562202       0.916705       2.896553       0
# 19-08-2019       0.531779       1.520466       0.983527       2.499107       0
# 16-08-2019       0.205265      -0.067823       0.436902       1.189072       0
# 14-08-2019      -0.525278      -0.521923      -1.485464      -1.201831       1
#             BJB-INR_close  BBA-INR_close  PNB-INR_close  YES-INR_close  target
# time
# 29-03-2019      -0.732960      -0.552821       0.961900       4.795735       0
# 29-01-2019      -1.268849      -1.074176      -1.329565      -1.545435       1
# 28-12-2018       0.807347       0.298553      -0.017342      -0.621676       0
# 29-11-2018      -0.117141      -1.047670      -0.828810      -0.680717       1
# 28-11-2018      -0.009282      -0.077627      -0.116947       0.062013       1

# %%
print(f"train data: {len(train_x)} validation: {len(validation_x)}")
print(f"Dont Buys : {train_y.count(0)}, buys: {train_y.count(1)}")
print(f"VALIDATION Dont Buys: {validation_y.count(0)}, buys: {validation_y.count(1)}")
# Out:
# train data: 2152 validation: 66
# Dont Buys : 1076, buys: 1076
# VALIDATION Dont Buys: 33, buys: 33

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, CuDNNLSTM, BatchNormalization
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

# %%
# !mkdir "models"
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %%
model = Sequential()

model.add(CuDNNLSTM(256, 
                    input_shape=(train_x.shape[1:]), 
                    return_sequences=True))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(CuDNNLSTM(256, 
                    input_shape=(train_x.shape[1:]), 
                    return_sequences=True))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(CuDNNLSTM(256, input_shape=(train_x.shape[1:])))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(2, activation='softmax'))

opt = tf.keras.optimizers.Adam(lr=0.0001, decay=1e-6)

# sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer= opt,
              metrics=['accuracy'])

model.summary()

history = model.fit(
    train_x, train_y,
    batch_size= BATCH_SIZE,
    epochs=24,
    validation_data=(validation_x,validation_y)
)
# Out:
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_211 (CuDNNLSTM)   (None, 20, 256)           268288
# _________________________________________________________________
# dropout_221 (Dropout)        (None, 20, 256)           0
# _________________________________________________________________
# batch_normalization_129 (Bat (None, 20, 256)           1024
# _________________________________________________________________
# cu_dnnlstm_212 (CuDNNLSTM)   (None, 20, 256)           526336
# _________________________________________________________________
# dropout_222 (Dropout)        (None, 20, 256)           0
# _________________________________________________________________
# batch_normalization_130 (Bat (None, 20, 256)           1024
# _________________________________________________________________
# cu_dnnlstm_213 (CuDNNLSTM)   (None, 256)               526336
# _________________________________________________________________
# dropout_223 (Dropout)        (None, 256)               0
# _________________________________________________________________
# batch_normalization_131 (Bat (None, 256)               1024
# _________________________________________________________________
# dense_131 (Dense)            (None, 32)                8224
# _________________________________________________________________
# dropout_224 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_132 (Dense)            (None, 2)                 66
# =================================================================
# Total params: 1,332,322
# Trainable params: 1,330,786
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 2152 samples, validate on 66 samples
# Epoch 1/24
# 2152/2152 [==============================] - 10s 5ms/sample - loss: 0.9045 - acc: 0.5200 - val_loss: 0.6924 - val_acc: 0.5455
# Epoch 2/24
# 2152/2152 [==============================] - 1s 287us/sample - loss: 0.8294 - acc: 0.5567 - val_loss: 0.6912 - val_acc: 0.5606
# Epoch 3/24
# 2152/2152 [==============================] - 0s 226us/sample - loss: 0.7993 - acc: 0.5446 - val_loss: 0.6906 - val_acc: 0.5455
# Epoch 4/24
# 2152/2152 [==============================] - 0s 229us/sample - loss: 0.7602 - acc: 0.5730 - val_loss: 0.6909 - val_acc: 0.5000
# Epoch 5/24
# 2152/2152 [==============================] - 0s 223us/sample - loss: 0.7456 - acc: 0.5920 - val_loss: 0.6877 - val_acc: 0.5303
# Epoch 6/24
# 2152/2152 [==============================] - 1s 234us/sample - loss: 0.7365 - acc: 0.5915 - val_loss: 0.6926 - val_acc: 0.5152
# Epoch 7/24
# 2152/2152 [==============================] - 0s 228us/sample - loss: 0.6911 - acc: 0.6055 - val_loss: 0.6956 - val_acc: 0.5000
# Epoch 8/24
# 2152/2152 [==============================] - 0s 227us/sample - loss: 0.7051 - acc: 0.6092 - val_loss: 0.6937 - val_acc: 0.5152
# Epoch 9/24
# 2152/2152 [==============================] - 0s 225us/sample - loss: 0.6937 - acc: 0.6185 - val_loss: 0.6888 - val_acc: 0.5152
# Epoch 10/24
# 2152/2152 [==============================] - 0s 232us/sample - loss: 0.6579 - acc: 0.6380 - val_loss: 0.6884 - val_acc: 0.4697
# Epoch 11/24
# 2152/2152 [==============================] - 0s 228us/sample - loss: 0.6640 - acc: 0.6287 - val_loss: 0.7001 - val_acc: 0.5000
# Epoch 12/24
# 2152/2152 [==============================] - 1s 233us/sample - loss: 0.6366 - acc: 0.6324 - val_loss: 0.7357 - val_acc: 0.4848
# Epoch 13/24
# 2152/2152 [==============================] - 0s 226us/sample - loss: 0.6257 - acc: 0.6543 - val_loss: 0.6932 - val_acc: 0.5152
# Epoch 14/24
# 2152/2152 [==============================] - 0s 227us/sample - loss: 0.6250 - acc: 0.6589 - val_loss: 0.7338 - val_acc: 0.5000
# Epoch 15/24
# 2152/2152 [==============================] - 0s 225us/sample - loss: 0.6299 - acc: 0.6566 - val_loss: 0.7099 - val_acc: 0.5455
# Epoch 16/24
# 2152/2152 [==============================] - 0s 231us/sample - loss: 0.6117 - acc: 0.6547 - val_loss: 0.6924 - val_acc: 0.5303
# Epoch 17/24
# 2152/2152 [==============================] - 0s 231us/sample - loss: 0.6100 - acc: 0.6696 - val_loss: 0.7302 - val_acc: 0.5000
# Epoch 18/24
# 2152/2152 [==============================] - 0s 231us/sample - loss: 0.5785 - acc: 0.7021 - val_loss: 0.7171 - val_acc: 0.5152
# Epoch 19/24
# 2152/2152 [==============================] - 0s 232us/sample - loss: 0.5772 - acc: 0.6984 - val_loss: 0.7211 - val_acc: 0.5000
# Epoch 20/24
# 2152/2152 [==============================] - 0s 229us/sample - loss: 0.5699 - acc: 0.6952 - val_loss: 0.7269 - val_acc: 0.5758
# Epoch 21/24
# 2152/2152 [==============================] - 0s 221us/sample - loss: 0.5753 - acc: 0.7007 - val_loss: 0.7356 - val_acc: 0.5606
# Epoch 22/24
# 2152/2152 [==============================] - 1s 236us/sample - loss: 0.5755 - acc: 0.6952 - val_loss: 0.7080 - val_acc: 0.5455
# Epoch 23/24
# 2152/2152 [==============================] - 0s 227us/sample - loss: 0.5706 - acc: 0.6984 - val_loss: 0.7399 - val_acc: 0.4848
# Epoch 24/24
# 2152/2152 [==============================] - 0s 227us/sample - loss: 0.5558 - acc: 0.7142 - val_loss: 0.7688 - val_acc: 0.5455

# %%
plot_history([('Model History',history)])

# %%
model = Sequential()  
model.add(CuDNNLSTM(256, input_shape=(train_x.shape[1:]), return_sequences=True))  
model.add(CuDNNLSTM(128, input_shape=(train_x.shape[1:]), return_sequences=False))  
model.add(Dense(32,activation='relu'))  
model.add(Dense(2,activation='softmax'))


opt = tf.keras.optimizers.Adam(lr=0.001, decay=1e-6)

# sgd = tf.keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer= opt,
              metrics=['accuracy'])

model.summary()

history = model.fit(
    train_x, train_y,
    batch_size= 16,
    epochs=28,
    validation_data=(validation_x,validation_y)
)
# Out:
# Model: "sequential_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_214 (CuDNNLSTM)   (None, 20, 256)           268288
# _________________________________________________________________
# cu_dnnlstm_215 (CuDNNLSTM)   (None, 128)               197632
# _________________________________________________________________
# dense_133 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dense_134 (Dense)            (None, 2)                 66
# =================================================================
# Total params: 470,114
# Trainable params: 470,114
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2152 samples, validate on 66 samples
# Epoch 1/28
# 2152/2152 [==============================] - 10s 5ms/sample - loss: 0.6939 - acc: 0.5270 - val_loss: 0.7282 - val_acc: 0.4697
# Epoch 2/28
# 2152/2152 [==============================] - 1s 476us/sample - loss: 0.6907 - acc: 0.5274 - val_loss: 0.6908 - val_acc: 0.5455
# Epoch 3/28
# 2152/2152 [==============================] - 1s 433us/sample - loss: 0.6882 - acc: 0.5390 - val_loss: 0.7073 - val_acc: 0.4545
# Epoch 4/28
# 2152/2152 [==============================] - 1s 435us/sample - loss: 0.6829 - acc: 0.5507 - val_loss: 0.6939 - val_acc: 0.5455
# Epoch 5/28
# 2152/2152 [==============================] - 1s 442us/sample - loss: 0.6768 - acc: 0.5632 - val_loss: 0.6851 - val_acc: 0.5606
# Epoch 6/28
# 2152/2152 [==============================] - 1s 448us/sample - loss: 0.6683 - acc: 0.5711 - val_loss: 0.7039 - val_acc: 0.5152
# Epoch 7/28
# 2152/2152 [==============================] - 1s 440us/sample - loss: 0.6641 - acc: 0.5771 - val_loss: 0.7124 - val_acc: 0.5000
# Epoch 8/28
# 2152/2152 [==============================] - 1s 432us/sample - loss: 0.6613 - acc: 0.5920 - val_loss: 0.6974 - val_acc: 0.5758
# Epoch 9/28
# 2152/2152 [==============================] - 1s 430us/sample - loss: 0.6522 - acc: 0.6069 - val_loss: 0.7069 - val_acc: 0.5303
# Epoch 10/28
# 2152/2152 [==============================] - 1s 430us/sample - loss: 0.6414 - acc: 0.6013 - val_loss: 0.7085 - val_acc: 0.5455
# Epoch 11/28
# 2152/2152 [==============================] - 1s 450us/sample - loss: 0.6293 - acc: 0.6343 - val_loss: 0.7023 - val_acc: 0.5758
# Epoch 12/28
# 2152/2152 [==============================] - 1s 435us/sample - loss: 0.6075 - acc: 0.6571 - val_loss: 0.7189 - val_acc: 0.4848
# Epoch 13/28
# 2152/2152 [==============================] - 1s 436us/sample - loss: 0.5855 - acc: 0.6812 - val_loss: 0.7125 - val_acc: 0.5303
# Epoch 14/28
# 2152/2152 [==============================] - 1s 432us/sample - loss: 0.5524 - acc: 0.6984 - val_loss: 0.7303 - val_acc: 0.5152
# Epoch 15/28
# 2152/2152 [==============================] - 1s 433us/sample - loss: 0.5288 - acc: 0.7282 - val_loss: 0.7581 - val_acc: 0.5606
# Epoch 16/28
# 2152/2152 [==============================] - 1s 430us/sample - loss: 0.4845 - acc: 0.7537 - val_loss: 0.7260 - val_acc: 0.5303
# Epoch 17/28
# 2152/2152 [==============================] - 1s 442us/sample - loss: 0.4604 - acc: 0.7728 - val_loss: 0.8902 - val_acc: 0.5303
# Epoch 18/28
# 2152/2152 [==============================] - 1s 436us/sample - loss: 0.4060 - acc: 0.8072 - val_loss: 0.9192 - val_acc: 0.4848
# Epoch 19/28
# 2152/2152 [==============================] - 1s 430us/sample - loss: 0.3779 - acc: 0.8230 - val_loss: 0.8326 - val_acc: 0.5455
# Epoch 20/28
# 2152/2152 [==============================] - 1s 429us/sample - loss: 0.3207 - acc: 0.8578 - val_loss: 1.3832 - val_acc: 0.4848
# Epoch 21/28
# 2152/2152 [==============================] - 1s 432us/sample - loss: 0.2779 - acc: 0.8806 - val_loss: 1.2482 - val_acc: 0.5000
# Epoch 22/28
# 2152/2152 [==============================] - 1s 441us/sample - loss: 0.2359 - acc: 0.9038 - val_loss: 1.4651 - val_acc: 0.5000
# Epoch 23/28
# 2152/2152 [==============================] - 1s 432us/sample - loss: 0.2069 - acc: 0.9075 - val_loss: 1.5317 - val_acc: 0.4848
# Epoch 24/28
# 2152/2152 [==============================] - 1s 425us/sample - loss: 0.1783 - acc: 0.9298 - val_loss: 1.5556 - val_acc: 0.4697
# Epoch 25/28
# 2152/2152 [==============================] - 1s 443us/sample - loss: 0.1547 - acc: 0.9382 - val_loss: 1.6115 - val_acc: 0.4697
# Epoch 26/28
# 2152/2152 [==============================] - 1s 436us/sample - loss: 0.1280 - acc: 0.9526 - val_loss: 1.5421 - val_acc: 0.5152
# Epoch 27/28
# 2152/2152 [==============================] - 1s 446us/sample - loss: 0.1037 - acc: 0.9600 - val_loss: 1.9673 - val_acc: 0.4545
# Epoch 28/28
# 2152/2152 [==============================] - 1s 437us/sample - loss: 0.0692 - acc: 0.9777 - val_loss: 2.1025 - val_acc: 0.4545

# %%
plot_history([('Model History',history)])

# %%
dropout = 0.2
model = Sequential()
model.add(CuDNNLSTM(256, return_sequences=True, input_shape=(train_x.shape[1:])))
model.add(Dropout(dropout))
model.add(CuDNNLSTM(256, return_sequences=True))
model.add(Dropout(dropout))
model.add(CuDNNLSTM(256))
model.add(Dropout(dropout))
model.add(Dense(2, activation = 'softmax'))


loss= "sparse_categorical_crossentropy"
opt = tf.keras.optimizers.Adam(lr=0.001, decay=1e-6)
model.compile(loss=loss, optimizer=opt, metrics=['accuracy'])

model.summary()

history = model.fit(
    train_x, train_y,
    batch_size= BATCH_SIZE,
    epochs=8,
    validation_data=(validation_x,validation_y)
)
# Out:
# Model: "sequential_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_222 (CuDNNLSTM)   (None, 20, 256)           268288
# _________________________________________________________________
# dropout_231 (Dropout)        (None, 20, 256)           0
# _________________________________________________________________
# cu_dnnlstm_223 (CuDNNLSTM)   (None, 20, 256)           526336
# _________________________________________________________________
# dropout_232 (Dropout)        (None, 20, 256)           0
# _________________________________________________________________
# cu_dnnlstm_224 (CuDNNLSTM)   (None, 256)               526336
# _________________________________________________________________
# dropout_233 (Dropout)        (None, 256)               0
# _________________________________________________________________
# dense_137 (Dense)            (None, 2)                 514
# =================================================================
# Total params: 1,321,474
# Trainable params: 1,321,474
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2152 samples, validate on 66 samples
# Epoch 1/8
# 2152/2152 [==============================] - 10s 4ms/sample - loss: 0.6941 - acc: 0.5107 - val_loss: 0.6951 - val_acc: 0.5000
# Epoch 2/8
# 2152/2152 [==============================] - 1s 257us/sample - loss: 0.6916 - acc: 0.5228 - val_loss: 0.6931 - val_acc: 0.5606
# Epoch 3/8
# 2152/2152 [==============================] - 0s 191us/sample - loss: 0.6894 - acc: 0.5325 - val_loss: 0.6964 - val_acc: 0.4697
# Epoch 4/8
# 2152/2152 [==============================] - 0s 184us/sample - loss: 0.6883 - acc: 0.5581 - val_loss: 0.6865 - val_acc: 0.4848
# Epoch 5/8
# 2152/2152 [==============================] - 0s 196us/sample - loss: 0.6856 - acc: 0.5441 - val_loss: 0.6965 - val_acc: 0.4848
# Epoch 6/8
# 2152/2152 [==============================] - 0s 189us/sample - loss: 0.6819 - acc: 0.5511 - val_loss: 0.6882 - val_acc: 0.5606
# Epoch 7/8
# 2152/2152 [==============================] - 0s 184us/sample - loss: 0.6789 - acc: 0.5576 - val_loss: 0.6868 - val_acc: 0.5152
# Epoch 8/8
# 2152/2152 [==============================] - 0s 186us/sample - loss: 0.6799 - acc: 0.5562 - val_loss: 0.6749 - val_acc: 0.5303

# %%
plot_history([('Model History',history)])

# %%
# We import matplotlib and create a function to plot history
import matplotlib.pyplot as plt

def plot_history(histories, key='acc'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])
